# %%
import sys
# !{sys.executable} -m pip install sqlalchemy mysql-connector-python
# Out:
# ...
# [notice] A new release of pip is available: 24.2 -> 26.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd
from sqlalchemy import create_engine

# %%
engine = create_engine("mysql+mysqlconnector://root:Chandru78100@localhost/retail_sales")

# %%
df_tables = pd.read_sql("SHOW TABLES;",engine)
df_tables
# Out:
#   Tables_in_retail_sales
# 0                 brands
# 1             categories
# 2      customer_segments
# 3              customers
# 4            order_items
# 5                 orders
# 6               products
# 7                 staffs
# 8                 stocks
# 9                 stores

# %%
import pandas as pd

# %%
orders=pd.read_sql("select * from orders",engine)
orders.head()
# Out:
#   order_id customer_id  order_status  order_date required_date shipped_date  \
# 0        1         259             4  01-01-2016    03-01-2016   03-01-2016
# 1       10         442             4  05-01-2016    06-01-2016   06-01-2016
# 2      100        1237             4  01-03-2016    04-03-2016   03-03-2016
# 3     1000         645             4  12-07-2017    14-07-2017   15-07-2017
# 4     1001         354             4  13-07-2017    16-07-2017   15-07-2017
#
#   store_id staff_id ship_status
# 0        1        2     Shipped
# 1        2        6     Shipped
# 2        2        7     Shipped
# 3        2        7     Shipped
# 4        2        6     Shipped

# %%
import pandas as pd

# %%
order_items=pd.read_sql("select * from order_items",engine)
order_items.head()
# Out:
#   order_id item_id product_id  quantity  list_price  discount  total price  \
# 0        1       1         20         1      599.99      0.20       599.79
# 1        1       2          8         2     1799.99      0.07      3599.91
# 2        1       3         10         2     1549.00      0.05      3097.95
# 3        1       4         16         2      599.99      0.05      1199.93
# 4        1       5          4         1     2899.99      0.20      2899.79
#
#                                  merge two column high and low
# 0  Electra Townie Original 7D EQ - Women's - 2016          low
# 1           Trek Remedy 29 Carbon Frameset - 2016          low
# 2                          Surly Straggler - 2016          low
# 3            Electra Townie Original 7D EQ - 2016          low
# 4                        Trek Fuel EX 8 29 - 2016          low

# %%
import pandas as pd

# %%
customers = pd.read_sql("select * from customers",engine)
customers.head()
# Out:
#   customer_id first_name last_name           phone                     email  \
# 0           1      Debra     Burks             #NA     debra.burks@yahoo.com
# 1          10    Pamelia    Newman             #NA  pamelia.newman@gmail.com
# 2         100     Kellie    Franco             #NA   kellie.franco@yahoo.com
# 3        1000     Shiloh    Reeves             #NA     shiloh.reeves@msn.com
# 4        1001        Lee     Roman  (631) 913-6967       lee.roman@gmail.com
#
#                   street          city state  zip_code
# 0      9273 Thorne Ave.   Orchard Park    NY     14127
# 1     476 Chestnut Ave.         Monroe    NY     10950
# 2  444 South Walnut Rd.        Commack    NY     11725
# 3     818 Kirkland Lane   West Babylon    NY     11704
# 4          4 Canal Ave.      Brentwood    NY     11717

# %%
orders.describe()
# Out:
#        order_status
# count   1615.000000
# mean       3.778947
# std        0.693430
# min        1.000000
# 25%        4.000000
# 50%        4.000000
# 75%        4.000000
# max        4.000000

# %%
order_items.describe()
# Out:
#           quantity   list_price     discount   total price
# count  3058.000000  3058.000000  3058.000000   3058.000000
# mean      1.497711  1106.583581     0.105801   1658.611622
# std       0.500077  1207.309610     0.058562   1999.807408
# min       1.000000   109.990000     0.050000    109.790000
# 25%       1.000000   429.000000     0.050000    539.780000
# 50%       1.000000   549.990000     0.070000    899.880000
# 75%       2.000000  1469.990000     0.200000   1739.930000
# max       2.000000  6499.990000     0.200000  12999.930000

# %%
customers.describe()
# Out:
#            zip_code
# count   1445.000000
# mean   34200.015225
# std    34733.933551
# min    10002.000000
# 25%    11419.000000
# 50%    11967.000000
# 75%    76110.000000
# max    95993.000000

# %%
orders.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1615 entries, 0 to 1614
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   order_id       1615 non-null   str
#  1   customer_id    1615 non-null   str
#  2   order_status   1615 non-null   int64
#  3   order_date     1615 non-null   str
#  4   required_date  1615 non-null   str
#  5   shipped_date   1445 non-null   str
#  6   store_id       1615 non-null   str
#  7   staff_id       1615 non-null   str
#  8   ship_status    1615 non-null   str
# dtypes: int64(1), str(8)
# memory usage: 113.7 KB

# %%
order_items.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 3058 entries, 0 to 3057
# Data columns (total 9 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   order_id          3058 non-null   str
#  1   item_id           3058 non-null   str
#  2   product_id        3058 non-null   str
#  3   quantity          3058 non-null   int64
#  4   list_price        3058 non-null   float64
#  5   discount          3058 non-null   float64
#  6   total price       3058 non-null   float64
#  7   merge two column  3058 non-null   str
#  8   high and low      3058 non-null   str
# dtypes: float64(3), int64(1), str(5)
# memory usage: 215.1 KB

# %%
customers.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1445 entries, 0 to 1444
# Data columns (total 9 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   customer_id  1445 non-null   str
#  1   first_name   1445 non-null   str
#  2   last_name    1445 non-null   str
#  3   phone        1445 non-null   str
#  4   email        1445 non-null   str
#  5   street       1445 non-null   str
#  6   city         1445 non-null   str
#  7   state        1445 non-null   str
#  8   zip_code     1445 non-null   int64
# dtypes: int64(1), str(8)
# memory usage: 101.7 KB

# %%
orders.value_counts()
# Out:
# order_id  customer_id  order_status  order_date  required_date  shipped_date  store_id  staff_id  ship_status
# 1         259          4             01-01-2016  03-01-2016     03-01-2016    1         2         Shipped        1
# 10        442          4             05-01-2016  06-01-2016     06-01-2016    2         6         Shipped        1
# 100       1237         4             01-03-2016  04-03-2016     03-03-2016    2         7         Shipped        1
# 1000      645          4             12-07-2017  14-07-2017     15-07-2017    2         7         Shipped        1
# 1001      354          4             13-07-2017  16-07-2017     15-07-2017    2         6         Shipped        1
#                                                                                                                 ..
# 995       621          4             11-07-2017  13-07-2017     14-07-2017    1         2         Shipped        1
# ...

# %%
order_items.value_counts()
# Out:
# order_id  item_id  product_id  quantity  list_price  discount  total price  merge two column                                high and low
# 1         1        20          1         599.99      0.20      599.79       Electra Townie Original 7D EQ - Women's - 2016  low             1
#           2        8           2         1799.99     0.07      3599.91      Trek Remedy 29 Carbon Frameset - 2016           low             1
#           3        10          2         1549.00     0.05      3097.95      Surly Straggler - 2016                          low             1
#           4        16          2         599.99      0.05      1199.93      Electra Townie Original 7D EQ - 2016            low             1
#           5        4           1         2899.99     0.20      2899.79      Trek Fuel EX 8 29 - 2016                        low             1
# ...

# %%
customers.value_count()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 customers.value_count()
#
# NameError: name 'customers' is not defined

# %%
pip install seaborn
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.2 -> 26.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import seaborn as sns

# %%
sns.countplot(x='ship_status',data=orders)
# Out:
# <Axes: xlabel='ship_status', ylabel='count'>

# %%
sns.boxplot(data=customers,x='state',y='zip_code')
# Out:
# <Axes: xlabel='state', ylabel='zip_code'>

# %%
items_price = order_items.groupby('item_id')['quantity'].sum()

# %%
items_price=items_price.reset_index()

# %%
items_price
# Out:
#   item_id  quantity
# 0       1      1576
# 1       2      1292
# 2       3       926
# 3       4       557
# 4       5       229

# %%
sns.violinplot(data=order_items,x='item_id',y='quantity')
# Out:
# <Axes: xlabel='item_id', ylabel='quantity'>

# %%
sns.histplot(data=customers,x='state')
# Out:
# <Axes: xlabel='state', ylabel='Count'>

# %%
import pandas as pd

# %%
pip install matplotlib
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.2 -> 26.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import matplotlib.pyplot as plt

# %%
plt.scatter(order_items['list_price'],order_items['total price'])

# %%
orderby=orders.groupby('order_id')['order_status'].sum()

# %%
oderby=orderby.reset_index()

# %%
orderby
# Out:
# order_id
# 1       4
# 10      4
# 100     4
# 1000    4
# 1001    4
#        ..
# 995     4
# 996     4
# 997     4
# 998     4
# 999     4
# Name: order_status, Length: 1615, dtype: int64

# %%
plt.bar(orders['order_status'],orders['ship_status'])
# Out:
# <BarContainer object of 1615 artists>

# %%
city_count=customers['city'].value_counts().head(5)
plt.pie(city_count.values,labels=city_count.index,autopct='%1.1f%%')
plt.title("top 5 cities")
plt.show()

# %%
df=orders[['customer_id','order_date']]
df
# Out:
#      customer_id  order_date
# 0            259  01-01-2016
# 1            442  05-01-2016
# 2           1237  01-03-2016
# 3            645  12-07-2017
# 4            354  13-07-2017
# ...          ...         ...
# 1610         621  11-07-2017
# 1611         915  11-07-2017
# 1612         485  11-07-2017
# 1613         219  12-07-2017
# 1614         590  12-07-2017
#
# [1615 rows x 2 columns]

# %%
current_date=pd.to_datetime('2026-04-24')
current_date
# Out:
# Timestamp('2026-04-24 00:00:00')

# %%
df['order_ date'] =pd.to_datetime(df['order_date'])

# %%
print(df.dtypes)
# Out:
# customer_id               str
# order_date     datetime64[us]
# recency                 int64
# order_ date    datetime64[us]
# dtype: object

# %%
df['recency']=(current_date-df['order_date']).dt.days
print(df)
# Out:
#      customer_id order_date  recency order_ date
# 0            259 2016-01-01     3766  2016-01-01
# 1            442 2016-01-05     3762  2016-01-05
# 2           1237 2016-03-01     3706  2016-03-01
# 3            645 2017-07-12     3208  2017-07-12
# 4            354 2017-07-13     3207  2017-07-13
# ...          ...        ...      ...         ...
# 1610         621 2017-07-11     3209  2017-07-11
# 1611         915 2017-07-11     3209  2017-07-11
# 1612         485 2017-07-11     3209  2017-07-11
# 1613         219 2017-07-12     3208  2017-07-12
# 1614         590 2017-07-12     3208  2017-07-12
#
# [1615 rows x 4 columns]

# %%
orders_count=orders.groupby('customer_id')['order_id'].agg(frequency='count')
orders_count
# Out:
#              frequency
# customer_id
# 1                    3
# 10                   3
# 100                  1
# 1000                 1
# 1001                 1
# ...                ...
# 995                  1
# 996                  1
# 997                  1
# 998                  1
# 999                  1
#
# [1445 rows x 1 columns]

# %%
merge_data=pd.merge(orders,order_items,on='order_id',how='inner')
merge_data
# Out:
#      order_id customer_id  order_status  order_date required_date  \
# 0           1         259             4  01-01-2016    03-01-2016
# 1           1         259             4  01-01-2016    03-01-2016
# 2           1         259             4  01-01-2016    03-01-2016
# 3           1         259             4  01-01-2016    03-01-2016
# 4           1         259             4  01-01-2016    03-01-2016
# ...       ...         ...           ...         ...           ...
# 3053      997         485             4  11-07-2017    13-07-2017
# 3054      998         219             4  12-07-2017    13-07-2017
# 3055      998         219             4  12-07-2017    13-07-2017
# 3056      999         590             4  12-07-2017    13-07-2017
# 3057      999         590             4  12-07-2017    13-07-2017
#
#      shipped_date store_id staff_id ship_status item_id product_id  quantity  \
# 0      03-01-2016        1        2     Shipped       1         20         1
# ...

# %%
merge_data['monetary']=merge_data['quantity']*merge_data['list_price']

orderspurchase=merge_data.groupby('customer_id')['monetary'].sum()

orderspurchase
# Out:
# customer_id
# 1        9937.95
# 10       2448.98
# 1000     2381.97
# 1001     4131.96
# 1004      299.99
#           ...
# 993       419.98
# 994      3720.95
# 995      5407.97
# 996       549.99
# 997     12080.95
# Name: monetary, Length: 1040, dtype: float64
